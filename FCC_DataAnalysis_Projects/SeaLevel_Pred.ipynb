# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('epa-sea-level.csv')

# %%
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
def draw_plot():
    # Read data from file
    df = pd.read_csv('epa-sea-level.csv')
    
    fit1 = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
    fit2 = linregress(df[df['Year']>= 2000]['Year'], df[df['Year']>= 2000]['CSIRO Adjusted Sea Level'])
    y = pd.Series(range(1880,2051)) # Rangle of years as Series from 1880 to 2050
    


    # Create scatter plot
    fig, ax = plt.subplots(figsize=(14, 9))
    
    ax.scatter(df['Year'], df['CSIRO Adjusted Sea Level'])

    # Create first line of best fit
    ax.plot(y,fit1.intercept + fit1.slope * y, '--r')

    # Create second line of best fit
    ax.plot(y,fit2.intercept + fit2.slope * y, '--g')

    # Add labels and title
    ax.set_xlabel('Year')
    ax.set_ylabel('Sea Level (inches)')
    ax.set_title('Rise in Sea Level')
    
    # Save plot and return data for testing (DO NOT MODIFY)
    plt.savefig('sea_level_plot.png')
    return plt.gca()

# %%
draw_plot()
# Out:
# <AxesSubplot:title={'center':'Rise in Sea Level'}, xlabel='Year', ylabel='Sea Level (inches)'>
